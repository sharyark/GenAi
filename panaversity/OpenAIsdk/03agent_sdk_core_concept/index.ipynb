# %% [markdown]
# # Multi-Agent with Tools Example

# %% [markdown]
# This notebook demonstrates a multi-agent setup using the OpenAI Agent SDK, where each agent is equipped with specific tools to perform its tasks. We will create a 'researcher' agent that can search the web and a 'writer' agent that can write content to a file.

# %%
from agents import Agent, Runner, AsyncOpenAI, OpenAIChatCompletionsModel, set_tracing_disabled, function_tool
from agents.extensions.models.litellm_model import LitellmModel

from dotenv import load_dotenv
import os
load_dotenv()
gemini_api_key = os.getenv("GOOGLE_API_KEY")

BASE_URL = os.getenv("EXAMPLE_BASE_URL") or "https://generativelanguage.googleapis.com/v1beta/"
API_KEY = os.getenv("EXAMPLE_API_KEY") or gemini_api_key
MODEL_NAME = os.getenv("EXAMPLE_MODEL_NAME") or "gemini-1.5-pro"
import nest_asyncio #this is needed to run async code in Jupyter notebooks
nest_asyncio.apply()
client = AsyncOpenAI(base_url=BASE_URL, api_key=API_KEY)
set_tracing_disabled(disabled=True)

# %% [markdown]
# ## The Agent Loop
# The agent loop is the core of the agent's operation. It's a continuous cycle where the agent:
# 1. **Receives a prompt:** This can be from a user or another agent.
# 2. **Thinks:** The agent's underlying model processes the prompt and decides on the best course of action. This might involve using a tool, handing off to another agent, or responding directly.
# 3. **Acts:** The agent executes the chosen action. This could be calling a tool's function, passing the task to a sub-agent, or generating a response.
# 4. **Observes:** The agent receives the result of its action (e.g., the output of a tool, the response from a sub-agent).
# 5. **Repeats:** The agent goes back to the 'Thinks' step, incorporating the new information to decide on the next action. This loop continues until the task is complete.

# %% [markdown]
# ### Sub-Agent 1: The Researcher

# %%
from duckduckgo_search import DDGS

@function_tool
def web_search(query: str) -> str:
    """Searches the web for the given query and returns the results."""
    with DDGS() as ddgs:
        results = [r for r in ddgs.text(query, max_results=3)]
    return str(results)
researcher_agent = Agent(
    model=OpenAIChatCompletionsModel(model=MODEL_NAME, openai_client=client),
    name="researcher_agent",
    instructions="You are an expert researcher. Use the web_search tool to find information on the given topic.",
    tools=[web_search],
    handoff_description="Use this agent to conduct research and find information on a specific topic."
)

# %% [markdown]
# ### Sub-Agent 2: The Writer

# %%
@function_tool
def write_file(file_path: str, content: str) -> str:
    """Writes the given content to a file at the specified path."""
    with open(file_path, 'w') as f:
        f.write(content)
    return f"Successfully wrote to {file_path}."

writer_agent = Agent(
    model=OpenAIChatCompletionsModel(model=MODEL_NAME, openai_client=client),
    name="writer_agent",
    instructions="You are an expert writer. Use the write_file tool to write the given content to a file.",
    tools=[write_file],
    handoff_description="Use this agent to write content to a file."
)

# %% [markdown]
# ### The Supervisor Agent

# %%
supervisor_agent = Agent(
    model=OpenAIChatCompletionsModel(model=MODEL_NAME, openai_client=client),
    name="supervisor",
    instructions="You are the supervisor. Your job is to coordinate the researcher and writer agents to complete the user's request. Hand off tasks to the appropriate agent.",
    handoffs=[researcher_agent, writer_agent]
)

# %% [markdown]
# ### Running the Agentic Workflow

# %%
# result = await 
await Runner.run(
    supervisor_agent,
    "Research the capabilities of the Gemini AI model and write a short summary to a file named 'gemini_summary.txt'.",
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Desktop/GenAi/panaversity/OpenAIsdk/.venv/lib/python3.12/site-packages/anyio/_core/_eventloop.py:162, in get_async_backend(asynclib_name)
#     161 try:
# --> 162     return loaded_backends[asynclib_name]
#     163 except KeyError:
#
# KeyError: 'asyncio'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# File ~/Desktop/GenAi/panaversity/OpenAIsdk/.venv/lib/python3.12/site-packages/httpcore/_async/connection_pool.py:228, in AsyncConnectionPool.handle_async_request(self, request)
#     225 with self._optional_thread_lock:
#     226     # Assign incoming requests to available connections,
#     227     # closing or creating new connections as required.
# --> 228     closing = self._assign_requests_to_connections()
#     229 await self._close_connections(closing)
#
# File ~/Desktop/GenAi/panaversity/OpenAIsdk/.venv/lib/python3.12/site-packages/httpcore/_async/connection_pool.py:328, in AsyncConnectionPool._assign_requests_to_connections(self)
#     327     self._connections.append(connection)
# --> 328     pool_request.assign_to_connection(connection)
#     329 elif idle_connections:
#     330     # log: "closing idle connection"
#
# File ~/Desktop/GenAi/panaversity/OpenAIsdk/.venv/lib/python3.12/site-packages/httpcore/_async/connection_pool.py:25, in AsyncPoolRequest.assign_to_connection(self, connection)
#      24 self.connection = connection
# ---> 25 self._connection_acquired.set()
#
# File ~/Desktop/GenAi/panaversity/OpenAIsdk/.venv/lib/python3.12/site-packages/httpcore/_synchronization.py:130, in AsyncEvent.set(self)
#     129 if not self._backend:
# --> 130     self.setup()
#     132 if self._backend == "trio":
#
# File ~/Desktop/GenAi/panaversity/OpenAIsdk/.venv/lib/python3.12/site-packages/httpcore/_synchronization.py:126, in AsyncEvent.setup(self)
#     125 elif self._backend == "asyncio":
# --> 126     self._anyio_event = anyio.Event()
#
# File ~/Desktop/GenAi/panaversity/OpenAIsdk/.venv/lib/python3.12/site-packages/anyio/_core/_synchronization.py:83, in __new__(cls)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/Desktop/GenAi/panaversity/OpenAIsdk/.venv/lib/python3.12/site-packages/anyio/_core/_eventloop.py:164, in get_async_backend(asynclib_name)
#     163 except KeyError:
# --> 164     module = import_module(f"anyio._backends._{asynclib_name}")
#     165     loaded_backends[asynclib_name] = module.backend_class
#
# File /usr/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:995, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/Desktop/GenAi/panaversity/OpenAIsdk/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py:72
#      71 from .._core._eventloop import claim_worker_thread, threadlocals
# ---> 72 from .._core._exceptions import (
#      73     BrokenResourceError,
#      74     BusyResourceError,
#      75     ClosedResourceError,
#      76     EndOfStream,
#      77     RunFinishedError,
#      78     WouldBlock,
#      79     iterate_exceptions,
#      80 )
#      81 from .._core._sockets import convert_ipv6_sockaddr
#
# ImportError: cannot import name 'RunFinishedError' from 'anyio._core._exceptions' (/home/hydra/Desktop/GenAi/panaversity/OpenAIsdk/.venv/lib/python3.12/site-packages/anyio/_core/_exceptions.py)
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/Desktop/GenAi/panaversity/OpenAIsdk/.venv/lib/python3.12/site-packages/anyio/_core/_eventloop.py:162, in get_async_backend(asynclib_name)
#     161 try:
# --> 162     return loaded_backends[asynclib_name]
#     163 except KeyError:
#
# KeyError: 'asyncio'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# File ~/Desktop/GenAi/panaversity/OpenAIsdk/.venv/lib/python3.12/site-packages/openai/_base_client.py:1529, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1528 try:
# -> 1529     response = await self._client.send(
#    1530         request,
#    1531         stream=stream or self._should_stream_response_body(request=request),
#    1532         **kwargs,
#    1533     )
#    1534 except httpx.TimeoutException as err:
#
# File ~/Desktop/GenAi/panaversity/OpenAIsdk/.venv/lib/python3.12/site-packages/httpx/_client.py:1629, in AsyncClient.send(self, request, stream, auth, follow_redirects)
#    1627 auth = self._build_request_auth(request, auth)
# -> 1629 response = await self._send_handling_auth(
#    1630     request,
#    1631     auth=auth,
#    1632     follow_redirects=follow_redirects,
#    1633     history=[],
#    1634 )
#    1635 try:
#
# File ~/Desktop/GenAi/panaversity/OpenAIsdk/.venv/lib/python3.12/site-packages/httpx/_client.py:1657, in AsyncClient._send_handling_auth(self, request, auth, follow_redirects, history)
#    1656 while True:
# -> 1657     response = await self._send_handling_redirects(
#    1658         request,
#    1659         follow_redirects=follow_redirects,
#    1660         history=history,
#    1661     )
#    1662     try:
#
# File ~/Desktop/GenAi/panaversity/OpenAIsdk/.venv/lib/python3.12/site-packages/httpx/_client.py:1694, in AsyncClient._send_handling_redirects(self, request, follow_redirects, history)
#    1692     await hook(request)
# -> 1694 response = await self._send_single_request(request)
#    1695 try:
#
# File ~/Desktop/GenAi/panaversity/OpenAIsdk/.venv/lib/python3.12/site-packages/httpx/_client.py:1730, in AsyncClient._send_single_request(self, request)
#    1729 with request_context(request=request):
# -> 1730     response = await transport.handle_async_request(request)
#    1732 assert isinstance(response.stream, AsyncByteStream)
#
# File ~/Desktop/GenAi/panaversity/OpenAIsdk/.venv/lib/python3.12/site-packages/httpx/_transports/default.py:394, in AsyncHTTPTransport.handle_async_request(self, request)
#     393 with map_httpcore_exceptions():
# --> 394     resp = await self._pool.handle_async_request(req)
#     396 assert isinstance(resp.stream, typing.AsyncIterable)
#
# File ~/Desktop/GenAi/panaversity/OpenAIsdk/.venv/lib/python3.12/site-packages/httpcore/_async/connection_pool.py:255, in AsyncConnectionPool.handle_async_request(self, request)
#     253     closing = self._assign_requests_to_connections()
# --> 255 await self._close_connections(closing)
#     256 raise exc from None
#
# File ~/Desktop/GenAi/panaversity/OpenAIsdk/.venv/lib/python3.12/site-packages/httpcore/_async/connection_pool.py:343, in AsyncConnectionPool._close_connections(self, closing)
#     341 async def _close_connections(self, closing: list[AsyncConnectionInterface]) -> None:
#     342     # Close connections which have been removed from the pool.
# --> 343     with AsyncShieldCancellation():
#     344         for connection in closing:
#
# File ~/Desktop/GenAi/panaversity/OpenAIsdk/.venv/lib/python3.12/site-packages/httpcore/_synchronization.py:208, in AsyncShieldCancellation.__init__(self)
#     207 elif self._backend == "asyncio":
# --> 208     self._anyio_shield = anyio.CancelScope(shield=True)
#
# File ~/Desktop/GenAi/panaversity/OpenAIsdk/.venv/lib/python3.12/site-packages/anyio/_core/_tasks.py:31, in CancelScope.__new__(cls, deadline, shield)
#      28 def __new__(
#      29     cls, *, deadline: float = math.inf, shield: bool = False
#      30 ) -> CancelScope:
# ---> 31     return get_async_backend().create_cancel_scope(shield=shield, deadline=deadline)
#
# File ~/Desktop/GenAi/panaversity/OpenAIsdk/.venv/lib/python3.12/site-packages/anyio/_core/_eventloop.py:164, in get_async_backend(asynclib_name)
#     163 except KeyError:
# --> 164     module = import_module(f"anyio._backends._{asynclib_name}")
#     165     loaded_backends[asynclib_name] = module.backend_class
#
# File /usr/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:995, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/Desktop/GenAi/panaversity/OpenAIsdk/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py:72
#      71 from .._core._eventloop import claim_worker_thread, threadlocals
# ---> 72 from .._core._exceptions import (
#      73     BrokenResourceError,
#      74     BusyResourceError,
#      75     ClosedResourceError,
#      76     EndOfStream,
#      77     RunFinishedError,
#      78     WouldBlock,
#      79     iterate_exceptions,
#      80 )
#      81 from .._core._sockets import convert_ipv6_sockaddr
#
# ImportError: cannot import name 'RunFinishedError' from 'anyio._core._exceptions' (/home/hydra/Desktop/GenAi/panaversity/OpenAIsdk/.venv/lib/python3.12/site-packages/anyio/_core/_exceptions.py)
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/Desktop/GenAi/panaversity/OpenAIsdk/.venv/lib/python3.12/site-packages/anyio/_core/_eventloop.py:162, in get_async_backend(asynclib_name)
#     161 try:
# --> 162     return loaded_backends[asynclib_name]
#     163 except KeyError:
#
# KeyError: 'asyncio'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 2
#       1 # result = await
# ----> 2 await Runner.run(
#       3     supervisor_agent,
#       4     "Research the capabilities of the Gemini AI model and write a short summary to a file named 'gemini_summary.txt'.",
#       5 )
#
# File ~/Desktop/GenAi/panaversity/OpenAIsdk/.venv/lib/python3.12/site-packages/agents/run.py:206, in run(cls, starting_agent, input, context, max_turns, hooks, run_config, previous_response_id, session)
#     203 """A list of output guardrails to run on the final output of the run."""
#     205 tracing_disabled: bool = False
# --> 206 """Whether tracing is disabled for the agent run. If disabled, we will not trace the agent run.
#     207 """
#     209 trace_include_sensitive_data: bool = field(
#     210     default_factory=_default_trace_include_sensitive_data
#     211 )
#     212 """Whether we include potentially sensitive data (for example: inputs/outputs of tool calls or
#     213 LLM generations) in traces. If False, we'll still create spans for these events, but the
#     214 sensitive data will not be included.
#     215 """
#
# File ~/Desktop/GenAi/panaversity/OpenAIsdk/.venv/lib/python3.12/site-packages/agents/run.py:412, in run(self, starting_agent, input, **kwargs)
#     355 @classmethod
#     356 def run_sync(
#     357     cls,
#    (...)    367     session: Session | None = None,
#     368 ) -> RunResult:
#     369     """
#     370     Run a workflow synchronously, starting at the given agent.
#     371
#     372     Note:
#     373         This just wraps the `run` method, so it will not work if there's already an
#     374         event loop (e.g. inside an async function, or in a Jupyter notebook or async
#     375         context like FastAPI). For those cases, use the `run` method instead.
#     376
#     377     The agent will run in a loop until a final output is generated. The loop runs:
#     378
#     379       1. The agent is invoked with the given input.
#     380       2. If there is a final output (i.e. the agent produces something of type
#     381          `agent.output_type`), the loop terminates.
#     382       3. If there's a handoff, we run the loop again, with the new agent.
#     383       4. Else, we run tool calls (if any), and re-run the loop.
#     384
#     385     In two cases, the agent may raise an exception:
#     386
#     387       1. If the max_turns is exceeded, a MaxTurnsExceeded exception is raised.
#     388       2. If a guardrail tripwire is triggered, a GuardrailTripwireTriggered
#     389          exception is raised.
#     390
#     391     Note:
#     392         Only the first agent's input guardrails are run.
#     393
#     394     Args:
#     395         starting_agent: The starting agent to run.
#     396         input: The initial input to the agent. You can pass a single string for a
#     397             user message, or a list of input items.
#     398         context: The context to run the agent with.
#     399         max_turns: The maximum number of turns to run the agent for. A turn is
#     400             defined as one AI invocation (including any tool calls that might occur).
#     401         hooks: An object that receives callbacks on various lifecycle events.
#     402         run_config: Global settings for the entire agent run.
#     403         previous_response_id: The ID of the previous response, if using OpenAI
#     404             models via the Responses API, this allows you to skip passing in input
#     405             from the previous turn.
#     406         conversation_id: The ID of the stored conversation, if any.
#     407         session: A session for automatic conversation history management.
#     408
#     409     Returns:
#     410         A run result containing all the inputs, guardrail results and the output of
#     411         the last agent. Agents may perform handoffs, so we don't know the specific
# --> 412         type of the output.
#     413     """
#     415     runner = DEFAULT_AGENT_RUNNER
#     416     return runner.run_sync(
#     417         starting_agent,
#     418         input,
#    (...)    425         session=session,
#     426     )
#
# File /usr/lib/python3.12/asyncio/tasks.py:385, in Task.__wakeup(self, future)
#     383 def __wakeup(self, future):
#     384     try:
# --> 385         future.result()
#     386     except BaseException as exc:
#     387         # This may also be a cancellation.
#     388         self.__step(exc)
#
# File /usr/lib/python3.12/asyncio/tasks.py:314, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     310 try:
#     311     if exc is None:
#     312         # We use the `send` method directly, because coroutines
#     313         # don't have `__iter__` and `__next__` methods.
# --> 314         result = coro.send(None)
#     315     else:
#     316         result = coro.throw(exc)
#
# File ~/Desktop/GenAi/panaversity/OpenAIsdk/.venv/lib/python3.12/site-packages/agents/run.py:960, in _run_single_turn(cls, agent, all_tools, original_input, generated_items, hooks, context_wrapper, run_config, should_run_agent_start_hooks, tool_use_tracker, previous_response_id)
#     957     streamed_result._event_queue.put_nowait(QueueCompleteSentinel())
#     958     break
# --> 960 if streamed_result.is_complete:
#     961     break
#     963 all_tools = await cls._get_all_tools(current_agent, context_wrapper)
#
# File ~/Desktop/GenAi/panaversity/OpenAIsdk/.venv/lib/python3.12/site-packages/agents/run.py:1121, in _get_new_response(cls, agent, system_prompt, input, output_schema, all_tools, handoffs, context_wrapper, run_config, tool_use_tracker, previous_response_id, prompt_config)
#    1114     streamed_result.is_complete = True
#    1115     streamed_result._event_queue.put_nowait(QueueCompleteSentinel())
#    1116     exc.run_data = RunErrorDetails(
#    1117         input=streamed_result.input,
#    1118         new_items=streamed_result.new_items,
#    1119         raw_responses=streamed_result.raw_responses,
#    1120         last_agent=current_agent,
# -> 1121         context_wrapper=context_wrapper,
#    1122         input_guardrail_results=streamed_result.input_guardrail_results,
#    1123         output_guardrail_results=streamed_result.output_guardrail_results,
#    1124     )
#    1125     raise
#    1126 except Exception as e:
#
# File ~/Desktop/GenAi/panaversity/OpenAIsdk/.venv/lib/python3.12/site-packages/agents/models/openai_chatcompletions.py:65, in get_response(self, system_instructions, input, model_settings, tools, output_schema, handoffs, tracing, previous_response_id, prompt)
#      50 async def get_response(
#      51     self,
#      52     system_instructions: str | None,
#    (...)     61     prompt: ResponsePromptParam | None = None,
#      62 ) -> ModelResponse:
#      63     with generation_span(
#      64         model=str(self.model),
# ---> 65         model_config=model_settings.to_json_dict() | {"base_url": str(self._client.base_url)},
#      66         disabled=tracing.is_disabled(),
#      67     ) as span_generation:
#      68         response = await self._fetch_response(
#      69             system_instructions,
#      70             input,
#    (...)     78             prompt=prompt,
#      79         )
#      81         message: ChatCompletionMessage | None = None
#
# File ~/Desktop/GenAi/panaversity/OpenAIsdk/.venv/lib/python3.12/site-packages/agents/models/openai_chatcompletions.py:273, in _fetch_response(self, system_instructions, input, model_settings, tools, output_schema, handoffs, span, tracing, stream, prompt)
#     265 else:
#     266     messages_json = json.dumps(
#     267         converted_messages,
#     268         indent=2,
#     269         ensure_ascii=False,
#     270     )
#     271     tools_json = json.dumps(
#     272         converted_tools,
# --> 273         indent=2,
#     274         ensure_ascii=False,
#     275     )
#     276     logger.debug(
#     277         f"{messages_json}\n"
#     278         f"Tools:\n{tools_json}\n"
#    (...)    281         f"Response format: {response_format}\n"
#     282     )
#     284 reasoning_effort = model_settings.reasoning.effort if model_settings.reasoning else None
#
# File ~/Desktop/GenAi/panaversity/OpenAIsdk/.venv/lib/python3.12/site-packages/openai/resources/chat/completions/completions.py:2603, in AsyncCompletions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    2557 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    2558 async def create(
#    2559     self,
#    (...)   2600     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    2601 ) -> ChatCompletion | AsyncStream[ChatCompletionChunk]:
#    2602     validate_response_format(response_format)
# -> 2603     return await self._post(
#    2604         "/chat/completions",
#    2605         body=await async_maybe_transform(
#    2606             {
#    2607                 "messages": messages,
#    2608                 "model": model,
#    2609                 "audio": audio,
#    2610                 "frequency_penalty": frequency_penalty,
#    2611                 "function_call": function_call,
#    2612                 "functions": functions,
#    2613                 "logit_bias": logit_bias,
#    2614                 "logprobs": logprobs,
#    2615                 "max_completion_tokens": max_completion_tokens,
#    2616                 "max_tokens": max_tokens,
#    2617                 "metadata": metadata,
#    2618                 "modalities": modalities,
#    2619                 "n": n,
#    2620                 "parallel_tool_calls": parallel_tool_calls,
#    2621                 "prediction": prediction,
#    2622                 "presence_penalty": presence_penalty,
#    2623                 "prompt_cache_key": prompt_cache_key,
#    2624                 "reasoning_effort": reasoning_effort,
#    2625                 "response_format": response_format,
#    2626                 "safety_identifier": safety_identifier,
#    2627                 "seed": seed,
#    2628                 "service_tier": service_tier,
#    2629                 "stop": stop,
#    2630                 "store": store,
#    2631                 "stream": stream,
#    2632                 "stream_options": stream_options,
#    2633                 "temperature": temperature,
#    2634                 "tool_choice": tool_choice,
#    2635                 "tools": tools,
#    2636                 "top_logprobs": top_logprobs,
#    2637                 "top_p": top_p,
#    2638                 "user": user,
#    2639                 "verbosity": verbosity,
#    2640                 "web_search_options": web_search_options,
#    2641             },
#    2642             completion_create_params.CompletionCreateParamsStreaming
#    2643             if stream
#    2644             else completion_create_params.CompletionCreateParamsNonStreaming,
#    2645         ),
#    2646         options=make_request_options(
#    2647             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    2648         ),
#    2649         cast_to=ChatCompletion,
#    2650         stream=stream or False,
#    2651         stream_cls=AsyncStream[ChatCompletionChunk],
#    2652     )
#
# File ~/Desktop/GenAi/panaversity/OpenAIsdk/.venv/lib/python3.12/site-packages/openai/_base_client.py:1794, in AsyncAPIClient.post(self, path, cast_to, body, files, options, stream, stream_cls)
#    1780 async def post(
#    1781     self,
#    1782     path: str,
#    (...)   1789     stream_cls: type[_AsyncStreamT] | None = None,
#    1790 ) -> ResponseT | _AsyncStreamT:
#    1791     opts = FinalRequestOptions.construct(
#    1792         method="post", url=path, json_data=body, files=await async_to_httpx_files(files), **options
#    1793     )
# -> 1794     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File ~/Desktop/GenAi/panaversity/OpenAIsdk/.venv/lib/python3.12/site-packages/openai/_base_client.py:1552, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1549 log.debug("Encountered Exception", exc_info=True)
#    1551 if remaining_retries > 0:
# -> 1552     await self._sleep_for_retry(
#    1553         retries_taken=retries_taken,
#    1554         max_retries=max_retries,
#    1555         options=input_options,
#    1556         response=None,
#    1557     )
#    1558     continue
#    1560 log.debug("Raising connection error")
#
# File ~/Desktop/GenAi/panaversity/OpenAIsdk/.venv/lib/python3.12/site-packages/openai/_base_client.py:1620, in AsyncAPIClient._sleep_for_retry(self, retries_taken, max_retries, options, response)
#    1617 timeout = self._calculate_retry_timeout(remaining_retries, options, response.headers if response else None)
#    1618 log.info("Retrying request to %s in %f seconds", options.url, timeout)
# -> 1620 await anyio.sleep(timeout)
#
# File ~/Desktop/GenAi/panaversity/OpenAIsdk/.venv/lib/python3.12/site-packages/anyio/_core/_eventloop.py:87, in sleep(delay)
#      80 async def sleep(delay: float) -> None:
#      81     """
#      82     Pause the current task for the specified duration.
#      83
#      84     :param delay: the duration, in seconds
#      85
#      86     """
# ---> 87     return await get_async_backend().sleep(delay)
#
# File ~/Desktop/GenAi/panaversity/OpenAIsdk/.venv/lib/python3.12/site-packages/anyio/_core/_eventloop.py:164, in get_async_backend(asynclib_name)
#     162     return loaded_backends[asynclib_name]
#     163 except KeyError:
# --> 164     module = import_module(f"anyio._backends._{asynclib_name}")
#     165     loaded_backends[asynclib_name] = module.backend_class
#     166     return module.backend_class
#
# File /usr/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:995, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/Desktop/GenAi/panaversity/OpenAIsdk/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py:72
#      64 from .. import (
#      65     CapacityLimiterStatistics,
#      66     EventStatistics,
#    (...)     69     abc,
#      70 )
#      71 from .._core._eventloop import claim_worker_thread, threadlocals
# ---> 72 from .._core._exceptions import (
#      73     BrokenResourceError,
#      74     BusyResourceError,
#      75     ClosedResourceError,
#      76     EndOfStream,
#      77     RunFinishedError,
#      78     WouldBlock,
#      79     iterate_exceptions,
#      80 )
#      81 from .._core._sockets import convert_ipv6_sockaddr
#      82 from .._core._streams import create_memory_object_stream
#
# ImportError: cannot import name 'RunFinishedError' from 'anyio._core._exceptions' (/home/hydra/Desktop/GenAi/panaversity/OpenAIsdk/.venv/lib/python3.12/site-packages/anyio/_core/_exceptions.py)

# %%
print(result.final_output)

# %% [markdown]
# Now, let's verify that the file was created.

# %%
with open('gemini_summary.txt', 'r') as f:
    print(f.read())
